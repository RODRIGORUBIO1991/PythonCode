# %% [markdown]
# <h1 align='center'> TP NÚMERO 3 CODER <h1>

# %% [markdown]
# **Introducción**
#
#
# Bienvenido a nuestro analisis dedicado a brindar información sobre empleos en el sector IT. En nuestro compromiso por ayudarte a tomar decisiones informadas sobre tu carrera, ofrecemos una herramienta en la que puedes calificar las empresas en las que has trabajado y compartir tus experiencias con la comunidad.
#
# Con el objetivo de hacer que esta información sea más accesible, nos hemos dado a la tarea de seleccionar y analizar datos estadísticos relevantes. En este sentido, hemos desarrollado un estudio que nos permitió obtener información valiosa sobre la situación laboral en el sector IT.
#
# Entre los principales analisis, investigamos sobre la cantidad de profesionales del sector IT y el tipo de género, sobre los salarios y si pueden variar significativamente según la experiencia y la permanencia en un puesto de trabajo, y si existe una inequidad de género en cuanto a la remuneración.
#
# En este informe, te presentaremos los hallazgos de nuestro estudio de una manera clara y accesible, utilizando visualizaciones de datos y análisis detallados para respaldar nuestras hipótesis. Además, te invitamos a leer el apartado de metodología para conocer los detalles del estudio y su alcance.
#
# Esperamos que esta información sea útil para ti y para nuestra comunidad de profesionales del sector IT. ¡Comencemos!

# %% [markdown]
# **Objetivo general**
# Proporcionar información clara y relevante sobre el sector IT que permita a los usuarios calificar empresas y tomar decisiones informadas sobre su carrera. Asimismo, ofrecer resultados estadísticos accesibles y comprensibles sobre el sector IT que ayuden a la comunidad a tener una mejor comprensión del mismo.

# %% [markdown]
# **Contexto Comercial**
# El sector de la tecnología de la información (IT) es uno de los más dinámicos y de más rápido crecimiento a nivel mundial. En este contexto, contar con información actualizada y confiable sobre las tendencias en la industria y las oportunidades laborales resulta fundamental tanto para las empresas como para los profesionales que buscan desarrollar su carrera en este sector.

# %% [markdown]
# Un problema comercial que puede surgir en el contexto de una plataforma colaborativa que comparte información sobre empleos en el sector IT es la calidad de la información que se comparte. Si los usuarios no están motivados para calificar y compartir información relevante, la plataforma puede perder valor y no ser de utilidad para las empresas y profesionales que la utilizan.
#
# Otro problema que puede surgir es la falta de confianza en la información que se comparte en la plataforma. Si los usuarios no están seguros de la veracidad de la información que se comparte, o si la plataforma no tiene medidas adecuadas para garantizar la calidad de la información, esto puede afectar la credibilidad y la utilidad de la plataforma.
#
# Por último, otro problema comercial que puede surgir es la competencia de otras plataformas que ofrecen servicios similares. Si hay otras plataformas que ofrecen información más actualizada, precisa y confiable, o que tienen una base de usuarios más grande y activa, la plataforma colaborativa puede tener dificultades para atraer y retener a sus usuarios y competir en el mercado.

# %% [markdown]
# **Hipotesis**
#
#
# *Hipotesis 1: Los hombres al menos triplican en cantidad de profesionales a las mujeres*
#
# *Hipotesis 2: La mayor cantidad de los profesionales se encuentran entre los 30 y 40 años*
#
# *Hipotesis 3: Existe inequidad de género porque los hombres tienen un salario mayor a las mujeres*
#
# *Hipotesis 4: Los salarios más altos corresponde a los técnicos con mayor cantidad de años de experiencia*
#
# *Hipotesis 5: Las personas que mantienen sus puestos de trabajo poseen mayor salarios que los profesionales que recién ingresan a las empresas. Se va a comparar a las personas que tienen menos de 5 años en un mismo puesto*

# %% [markdown]
# **Conclusiones Hipotesis**
#
# *Hipotesis 1: Verdadero. Prácticamente hay 5 veces más hombres que mujeres en el sector*
#
# *Hipotesis 2: Falso. La mayor cantidad de los profesionales se encuentran entre los 25 y 35 años*
#
# *Hipotesis 3: Verdadero. Prácticamente el salario promedio de un hombre es 20% mayor al de una mujer promedio*
#
# *Hipotesis 4: Dudoso. Los salarios más altos corresponden a los técnicos que poseen más de 10 años de experiencia. Luego hay un estancamiento en el salario. Es decir que una persona que tiene 20 años no suele ganar más de una que tiene 10 años*
#
# *Hipotesis 5: Falso. No se puede identificar una correlación entre los salarios y el tiempo de pertenencia en un puesto laboral*

# %% [markdown]
# **Conclusiones**
#
# En conclusión, nuestro estudio ha permitido confirmar la hipótesis 1, la cual afirma que la cantidad de hombres en el sector IT supera significativamente a la cantidad de mujeres. Esta brecha de género, aunque ha disminuido en los últimos años, sigue siendo un problema importante en la industria.
#
# Por otro lado, la hipótesis 2 resultó ser falsa. En realidad, la mayor cantidad de profesionales del sector se encuentran entre los 25 y 35 años de edad, y no entre los 30 y 40 como se había supuesto originalmente.
#
# Con respecto a la hipótesis 3, se confirmó la existencia de una inequidad salarial de género, ya que los hombres tienen un salario promedio un 20% mayor al de las mujeres. Esta brecha salarial es un problema grave que necesita ser abordado para lograr una mayor igualdad en el sector IT.
#
# En cuanto a la hipótesis 4, los datos no permiten confirmarla de manera clara. Aunque es cierto que los salarios más altos corresponden a los técnicos con más de 10 años de experiencia, no se puede afirmar que los salarios se estancan luego de este punto. Se necesita mayor investigación para determinar si esto es cierto o no.
#
# Finalmente, la hipótesis 5 resultó ser falsa. Los datos no muestran una correlación significativa entre el salario y el tiempo de permanencia en un puesto de trabajo. De hecho, hay casos en los que profesionales que han mantenido su puesto de trabajo por menos de 5 años tienen salarios más altos que aquellos con más tiempo en la misma empresa.
#
# En resumen, nuestro estudio ha permitido obtener información valiosa sobre la situación laboral en el sector IT y ha confirmado algunas hipótesis, mientras que otras necesitan mayor investigación para ser confirmadas o descartadas. Es necesario seguir trabajando para mejorar la igualdad de género y salarial en la industria y para brindar información más detallada sobre la situación laboral de los profesionales del sector IT.

# %% [markdown]
# **Contexto Analitico**
# Las hipótesis presentadas sugieren una posible desigualdad de género en el sector IT en términos de cantidad de profesionales y salarios.
#
# La hipótesis 1 indica que la cantidad de hombres en el sector es significativamente mayor que la cantidad de mujeres. Si esta hipótesis se verifica, podría haber una explicación en términos de desigualdad de oportunidades para las mujeres en este campo de trabajo.
#
# La hipótesis 2 sugiere que los profesionales en este sector tienen una edad promedio específica. Si esta hipótesis se verifica, podría ayudar a las empresas a entender mejor la demografía de los trabajadores en el sector y cómo ajustar su estrategia de reclutamiento y formación.
#
# La hipótesis 3 indica una posible inequidad salarial entre hombres y mujeres en el sector. Si esta hipótesis se verifica, podrían tomarse medidas para abordar y reducir la brecha salarial.
#
# La hipótesis 4 sugiere que hay una relación entre la experiencia y el salario de los técnicos. Si esta hipótesis se verifica, podría ayudar a las empresas a entender cómo recompensar adecuadamente la experiencia y la habilidad de sus empleados.
#
# La hipótesis 5 indica una posible relación entre el tiempo de permanencia en un puesto y el salario. Si esta hipótesis se verifica, podrían tomarse medidas para retener a los empleados y ofrecer incentivos a los empleados nuevos para que se queden en la empresa.
#
# En general, las hipótesis presentadas proporcionan información valiosa para las empresas del sector IT, ayudando a entender mejor las características de los trabajadores y su compensación, y a diseñar estrategias más efectivas para el reclutamiento, la retención y la compensación de su personal.

# %% [markdown]
# **EXPLORACIÓN DE DATOS**

# %% [markdown]
# **importando librerias y cargando el Dataset**

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

import matplotlib.pyplot as plt
plt.style.use('classic')


url = 'https://raw.githubusercontent.com/eea-uba/EEA-2022/main/Fuentes/Encuesta%20de%20remuneracion%20salarial%20-%202020.1.csv'
df = pd.read_csv(url, index_col=0)

# %% [markdown]
# **Info en general**

# %%
df.head(1)

df.describe

# %% [markdown]
# **Borro Columnas y cambios de nombres de columnas**

# %%
#Cambio nombre de Me identifico por Genero

df.rename(columns= {"Me identifico":"Genero"}, inplace = True)

#Cambio nombre de Tengo por Edad
df.rename(columns= {"Tengo":"Edad"}, inplace = True)

#Quito lo de tu moneda local

df.rename(columns= {"Salario mensual BRUTO (en tu moneda local)":"SalarioB"}, inplace = True)


df.rename(columns= {"Salario mensual NETO (en tu moneda local)":"SalarioN"}, inplace = True)


#Borrar varias columnas que no tienen datos, todos trabajan en Argentina
df = df.drop(columns=['Estoy trabajando en', 'Dónde estás trabajando','Bolivia', 'Chile', 'Colombia', 'Cuba', 'Costa Rica', 'Ecuador','El Salvador', 'Guatemala', 'Honduras', 'México', 'Nicaragua', 'Panamá',
'Paraguay', 'Perú', 'Puerto Rico', 'República Dominicana', 'Uruguay'])

#Forma de borrar solo una columna
del df['Venezuela']

df.columns
# Out:
# Index(['Genero', 'Edad', 'Años de experiencia', 'Años en la empresa actual',
#        'Años en el puesto actual', '¿Gente a cargo?',
#        'Nivel de estudios alcanzado', 'Estado', 'Carrera', 'Universidad',
#        'Realizaste cursos de especialización',
#        '¿Contribuís a proyectos open source?', '¿Programás como hobbie?',
#        'Trabajo de', 'Plataformas', 'Lenguajes de programación',
#        'Frameworks, herramientas y librerías', 'Bases de datos',
#        'QA / Testing', 'IDEs', '¿Qué SO usás en tu laptop/PC para trabajar?',
#        '¿Y en tu celular?', '¿Tenés guardias?', 'Cuánto cobrás por guardia',
#        '¿Porcentaje, bruto o neto?', 'Tipo de contrato', 'SalarioB',
#        'SalarioN', '¿Qué tan conforme estás con tu sueldo?',
#        'Cómo creés que está tu sueldo con respecto al último semestre',
#        'Recibís algún tipo de bono', 'A qué está atado el bono',
#        '¿Tuviste ajustes por inflación en 2019?',
# ...

# %% [markdown]
# **Ver la cantidad de Null**

# %%
def missing_data(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    return pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data(df)
# Out:
#                                                     Total    Percent
# ¿Tenés algún tipo de discapacidad?                   5455  91.190237
# ¿Sos miembro de alguna comunidad IT?                 4511  75.409562
# ¿Cuáles considerás que son las mejores empresas...   4294  71.782013
# ¿A qué eventos de tecnología asististe en el úl...   3861  64.543631
# QA / Testing                                         3803  63.574055
# ¿Sentís que esto te dificultó el conseguir trab...   3019  50.468071
# Frameworks, herramientas y librerías                 2319  38.766299
# IDEs                                                 1704  28.485456
# Bases de datos                                       1483  24.791040
# Lenguajes de programación                            1102  18.421932
# Plataformas                                          1098  18.355065
# Universidad                                           626  10.464728
# Carrera                                               338   5.650284
# ...

# %% [markdown]
# **Ver los datos en una tabla de la columna Universidad**

# %%
df['Universidad'].value_counts(normalize=True)
# Out:
# UTN - Universidad Tecnológica Nacional                    0.237677
# UBA - Universidad de Buenos Aires                         0.155153
# UADE - Universidad Argentina De la Empresa                0.042569
# UNLaM - Universidad Nacional de La Matanza                0.036781
# UAI - Universidad Abierta Interamericana                  0.030433
#                                                             ...
# extranjero                                                0.000187
# UNLPam                                                    0.000187
# IUTV - Instituto Universitario de Tecnología Venezuela    0.000187
# Auto didacta                                              0.000187
# MLEC - Miami Lakes Educational Center                     0.000187
# Name: Universidad, Length: 850, dtype: float64

# %% [markdown]
# **Vemos cuantos estudiaron en la UTN. 1277 en total.**

# %%
filt = df['Universidad'].str.contains('UTN', na=False).value_counts()
filt
# Out:
# False    4705
# True     1277
# Name: Universidad, dtype: int64

# %% [markdown]
# **Ver la edad de los que aparecen en la UTN**

# %%
filt = df['Universidad'].str.contains('UTN', na=False)
#df[filt]["Edad"]
filtered_df = df[filt]
age_column = filtered_df["Edad"]
age_column
# Out:
# Timestamp
# 1/28/2020 21:57:28     35
# 1/21/2020 8:28:03      31
# 1/23/2020 19:38:41     46
# 1/29/2020 23:19:36     25
# 1/23/2020 0:39:39      27
#                        ..
# 2/2/2020 1:30:51       28
# 12/14/2019 12:16:59    41
# 12/14/2019 21:01:11    41
# 1/29/2020 14:06:24     35
# 2/2/2020 4:45:31       25
# Name: Edad, Length: 1277, dtype: int64

# %% [markdown]
# **Saco la edad promedio de cada universidad de la UTN.
# Para ver hay alguna diferencia
# A simple vista se podría decir que la Universidad
# IT y UTN posee una edad más baja**

# %%
plt.figure(figsize=(7, 5))
fig=plt.figure()

filtered_df.groupby('Universidad')['Edad'].mean().plot.bar()
fig.set_facecolor("white")

# %% [markdown]
# **Armo una tabla para mejorar visualización**

# %%
filtered_df =filtered_df[["Edad", "Universidad"]].style.set_caption("Tabla de Edad y Universidad")

# %% [markdown]
# **Edad Promedio y visualizar solo a los que tienen más de 30**

# %%
Edad_Promedio = df["Edad"].mean()
print(Edad_Promedio)

Mayores_30 = (df["Edad"] > 30).value_counts()
print(Mayores_30)
# Out:
# 32.09862922099632
# True     3103
# False    2879
# Name: Edad, dtype: int64

# %% [markdown]
# **Verificamos si hay nulos primero**

# %%
df.isnull().sum()
# Out:
# Genero                                                                                                   0
# Edad                                                                                                     0
# Años de experiencia                                                                                      0
# Años en la empresa actual                                                                                0
# Años en el puesto actual                                                                                 0
# ¿Gente a cargo?                                                                                          0
# Nivel de estudios alcanzado                                                                              0
# Estado                                                                                                   0
# Carrera                                                                                                338
# ...

# %% [markdown]
# **Hipotesis 1**
#
# *Hipotesis 1: Los hombres al menos triplican en cantidad de profesionales a las mujeres*
#
# **Conclusión 1**
#
# *Hipotesis 1: Verdadero. Prácticamente hay 5 veces más hombres que mujeres en el sector*
#
#
#
# **Gráfico de torta**
#
# Se ve la predominancia del género masculino en el sector IT

# %%
fig=plt.figure()
df["Genero"].value_counts().plot(kind="pie",autopct="%.2f%%")
plt.title ("Porcentaje por Genero", color='black', fontsize=25)
plt.tight_layout() #evitar el superposicionamiento
fig.set_facecolor("white")
plt.show()

# %% [markdown]
# **Gráfico de barras**
#
# Es lo mismo que el anterior en otra matriz gráfica**

# %%
fig=plt.figure()
df["Genero"].value_counts().plot(kind="bar")
plt.tight_layout() #evitar el superposicionamiento
plt.title("Gráfico de barras por Genero", color='black', fontsize=25)
plt.xlabel("Genero", color='white')
plt.ylabel("Cantidad", color="white")
plt.grid(True) #Para en forma de cuadricula
fig.set_facecolor("white")

# %% [markdown]
# **Gráfico de tortas**
#
# Para ver los porcentajes de los 3 grupos diferenciados en la encuesta.
# Una paridad muy importante en las tres

# %%
fig=plt.figure()
colors = ['orange', 'blue', 'green']
df['Actividad principal'].value_counts().plot(kind="pie",autopct="%.2f%%", legend=False)
plt.title("Gráfico de Torta por Actividad", color='black', fontsize=20)
fig.set_facecolor("white")
plt.show()

# %% [markdown]
# **Gráfico de tortas**
#
# Vemos lo mismo en un gráfico de barras, es lo mismo que el anterior en otra matriz gráfica.

# %%
colors = ['orange', 'blue', 'green']
fig=plt.figure()
df["Actividad principal"].value_counts().plot(kind="bar", color=colors, edgecolor='white')
plt.title("Gráfico de barras por Actividad", color='black', fontsize=20)
plt.xlabel("Genero", color='black', labelpad=10)
plt.ylabel("Cantidad", color="black")
plt.xticks(rotation=45)
plt.figure(figsize=(10,5))
fig.set_facecolor("white")
plt.show()

# %% [markdown]
# Vemos lo mismo sin gráficos, solo sumando los valores de cada actividad

# %%
df['Actividad principal'].value_counts()

# %% [markdown]
# **Hipotesis 2**
#
# *Hipotesis 2: La mayor cantidad de los profesionales se encuentran entre los 30 y 40 años*
#
# **Conclusión 2**
#
# *Hipotesis 2: Falso. La mayor cantidad de los profesionales se encuentran entre los 25 y 35 años*
#
#
# **Histograma de las edades**
#
# Nos sirve para ver que los grupos etarios predominantes son entre 25 y 35 años. Bajando de forma importante a medida que sube la edad.

# %%
fig=plt.figure()
plt.hist(df["Edad"], 10, color="blue", ec="black")
plt.title("Histograma", color='black', fontsize=20)
plt.xlabel("Edades")
plt.ylabel("Cantidad de profesionales")
fig.set_facecolor("white")

# %% [markdown]
# **Histograma de las edades (Version Seaborn)**
#
#  Es más sencillo el armado del gráfico y tiene algunos puntos extras como la demarcación de ciertas edades

# %%
fig=plt.figure()
sns.distplot(df['Edad'])
sns.distplot(df['Edad'], color='blue')
plt.title("Distribución de la edad", color='black', fontsize=20)
fig.set_facecolor("white")

# %% [markdown]
# **Gráfico de Violin**
#
# Combina las variables de Genero y Edad. Similares en los 3 tipos.
#
# Siempre las edades entre 25 y 35 poseen mayor relevancia.

# %%
fig=plt.figure()
sns.violinplot(data=df, x='Genero', y='Edad')
plt.title("Distribución de la edad por genero", color='black', fontsize=20)
fig.set_facecolor("white")

# %% [markdown]
# **Gráfico de 3 variables**
#
# La verdad es que no logro obtener información relevante pero es un ejemplo de lo que se puede realizar con
# este tipos de gráficos

# %%
fig=plt.figure()
sns.catplot(x='Actividad principal', y='Edad', hue='Genero', kind="swarm", data=df)
fig.set_facecolor("white")
# Out:
# c:\Users\rodri\miniconda3\envs\coder\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 68.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\rodri\miniconda3\envs\coder\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 70.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\rodri\miniconda3\envs\coder\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 61.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\rodri\miniconda3\envs\coder\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 86.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# **Comparación Edades con las actividades**
#
# Simplemente podemos indicar que en "otras industrias" hay un poco de más edad en los trabajadores promedios del sector. Solo de unos 2 o 3 años más.

# %%
fig=plt.figure()
sns.boxplot(data=df, x='Edad', y="Actividad principal")
plt.title("Gráfico de Boxplot de la edad por genero", color='black', fontsize=20)
fig.set_facecolor("white")

# %% [markdown]
# **Agrupamos en Genero y Actividad principal para comenzar a armar un gráfico combinado**

# %%
actividad_genero = df.groupby(["Genero","Actividad principal"]).size()
actividad_genero
# Out:
# Genero  Actividad principal
# Hombre  Otras industrias                                 1511
#         Producto basado en Software                      1751
#         Servicios / Consultoría de Software / Digital    1746
# Mujer   Otras industrias                                  277
#         Producto basado en Software                       257
#         Servicios / Consultoría de Software / Digital     328
# Otros   Otras industrias                                    7
#         Producto basado en Software                        12
#         Servicios / Consultoría de Software / Digital       9
# dtype: int64

# %% [markdown]
# Colocamos el reset_index

# %%
actividad_genero = actividad_genero.reset_index()
actividad_genero
# Out:
#    Genero                            Actividad principal     0
# 0  Hombre                               Otras industrias  1511
# 1  Hombre                    Producto basado en Software  1751
# 2  Hombre  Servicios / Consultoría de Software / Digital  1746
# 3   Mujer                               Otras industrias   277
# 4   Mujer                    Producto basado en Software   257
# 5   Mujer  Servicios / Consultoría de Software / Digital   328
# 6   Otros                               Otras industrias     7
# 7   Otros                    Producto basado en Software    12
# 8   Otros  Servicios / Consultoría de Software / Digital     9

# %% [markdown]
# Armamos la tabla pivot

# %%
actividad_genero = pd.pivot_table(actividad_genero, columns = "Actividad principal", index = "Genero", values=0)
actividad_genero
# Out:
# Actividad principal  Otras industrias  Producto basado en Software  \
# Genero
# Hombre                           1511                         1751
# Mujer                             277                          257
# Otros                               7                           12
#
# Actividad principal  Servicios / Consultoría de Software / Digital
# Genero
# Hombre                                                        1746
# Mujer                                                          328
# Otros                                                            9

# %% [markdown]
# **Grafico de barras**
#
# La realidad es que no es muy claro de esta forma

# %%
actividad_genero.plot (kind = "bar", title ="Grafico de barras Genero y Actividades")
plt.legend(prop={'size': 10}, bbox_to_anchor=(1,1))
ax.set_axisbelow(True)
ax.grid(True, color='white')
fig=plt.figure()

# %% [markdown]
# **Grafico de barras apiladas**
#
# Aquí mejora mucho la presentación gráfica.
#
#
# Volvemos a contemplar que las actividades tienen porcentajes similares en cada género y que la cantidad es muy superior en el género masculino

# %%
plt.figure(facecolor='white')
actividad_genero.plot (kind = "bar", stacked=True)
ax.set_axisbelow(True)
ax.grid(True, color='white')
plt.legend(prop={'size': 10}, bbox_to_anchor=(1,1))

# %% [markdown]
# Observo los outliers de la Columna

# %%
df["SalarioB"].sort_values()[:30]

# %% [markdown]
# Remuevo los 2 salarios más altos

# %%
df.drop([763, 4189], axis=0, inplace=True)

# %% [markdown]
# Con Boxplot se observa que hay varios outliers.

# %%
fig=plt.figure()
sns.boxplot(x=df['SalarioB'])
fig.set_facecolor("white")

# %% [markdown]
# Se toma una opción de eliminar los 20 valores más altos

# %%
idx = df['SalarioB'].sort_values(ascending=False)[:20].index
df.drop(idx, axis=0, inplace=True)

# %% [markdown]
# El grafico de distribucion mejora sin esos outliers

# %%
fig=plt.figure()
sns.histplot(data=df, x='SalarioB')
fig.set_facecolor("white")

# %% [markdown]
# Claramente tenemos outliers años en la empresa actual y en el puesto actual, Parece que es un solo valor en cada variable. Entonces.... los eliminemos

# %%
df_indexed = df.reset_index()

print(df['Años en la empresa actual'].sort_values(ascending=False)[:5])

print(df['Años en el puesto actual'].sort_values(ascending=False)[:5])

# %% [markdown]
# Hay dos errores claros, un dato que dice 2016 y otro que dice 85000. Por eso los elimino.

# %%
df = df[df['Años en la empresa actual'] != 2016]

df = df[df['Años en la empresa actual'] != 88]


df = df[df['Años en el puesto actual'] != 85000]

# %%
df_indexed = df.reset_index()
top_5_values = df_indexed['Años en la empresa actual'].sort_values(ascending=False)[:5]
print(top_5_values)
# Out:
# 516     40.0
# 5834    36.0
# 3953    34.0
# 2139    33.0
# 4069    33.0
# Name: Años en la empresa actual, dtype: float64
# C:\Users\rodri\AppData\Local\Temp\ipykernel_18596\588049225.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   top_5_values = df_indexed['Años en la empresa actual'].sort_values(ascending=False)[:5]

# %%
df_indexed = df.reset_index()
top_5_values = df_indexed['Años en el puesto actual'].sort_values(ascending=False)[:5]
print(top_5_values)

# %%
sns.set_style("whitegrid", {'axes.grid' : False})
sns.pairplot(df_exp, size=4)
# Out:
# c:\Users\rodri\miniconda3\envs\coder\lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Para los salarios, saco los 20 valores más altos y los 20 más bajos para mejorar los gráficos. Sé que no es lo mejor para hacer estos gráficos
# no encuentro otra opción

# %%
df = df.sort_values('SalarioB', ascending=True).iloc[20:-20]

# %% [markdown]
# **Reviso y ahora el promedio es lógico**

# %%
df["SalarioB"].mean()

# %% [markdown]
# **Histograma de los salarios con SNS**

# %%
sns.histplot(data=df, x='SalarioB', bins=8)
sns.set(rc={'figure.figsize':(8,8)})

# %%
#Un Histograma de los salarios con plt
fig=plt.figure()
plt.hist(df["SalarioB"], 8, color="blue", ec="black")
plt.title("Histograma de los Salarios", color='black', fontsize=20)
plt.xlabel("Salarios")
plt.ylabel("Cantidad de profesionales")
fig.set_facecolor("white")

# %% [markdown]
# Lo mismo con SNS

# %%
sns.distplot(df['Años en la empresa actual'], bins=30)
plt.xlabel('Años en la empresa actual')
plt.ylabel('Density')
plt.title('Histograma de Años en la empresa actual y sus salarios')
plt.show()
# Out:
# C:\Users\rodri\AppData\Local\Temp\ipykernel_18596\1002073532.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Años en la empresa actual'], bins=30)

# %% [markdown]
# **Hipotesis 3**
#
# *Hipotesis 3: Existe inequidad de género porque los hombres tienen un salario mayor a las mujeres*
#
# **Conclusión 3**
#
# *Hipotesis 3: Verdadero. Prácticamente el salario promedio de un hombre es 20% mayor al de una mujer promedio*
#
#
# Se puede ver que el salario de los hombres es mayor al femenino.
#
# Y Otros, tiene una base muy pequeña (pocos datos), generando mucha amplitud en sus valores
# No lo consideraria en el análisis por tener una muestra tan minuscula

# %%
sns.barplot(x='Genero', y='SalarioB', data=df)
# Out:
# <AxesSubplot: xlabel='Genero', ylabel='SalarioB'>

# %% [markdown]
# **Boxplot**
# Se contempla mejor que en el gráfico anterior las diferencias de los valores.

# %%
sns.boxplot(x='Genero', y='SalarioB', data=df)
# Out:
# <AxesSubplot: xlabel='Genero', ylabel='SalarioB'>

# %% [markdown]
# Agrupo las dos columnas que quiero comparar

# %%
Salario_genero = df.groupby('Genero')['SalarioB'].mean()

# %% [markdown]
# Saco la diferencia de porcentaje

# %%
Diferencia_Porcentaje = (Salario_genero['Mujer'] - Salario_genero['Hombre']) / Salario_genero['Hombre'] * 100

# %% [markdown]
# **Imprimo la diferencia con un texto**

# %%
print("La diferencia del Porcentaje entre el Salario Femenino y Masculino es de: {:.2f}%".format(Diferencia_Porcentaje))
# Out:
# La diferencia del Porcentaje entre el Salario Femenino y Masculino es de: -20.66%

# %% [markdown]
# Uso un gráfico de dispersión para ver si podría indicar si hay mejores salarios para quienes tienen mayores años en las empresas.
#
# Pero viendo el gráfico, la realidad es que no hay correlación

# %%
plt.scatter(df['Años en la empresa actual'], df['SalarioB'])
plt.xlabel('Años en la empresa actual')
plt.ylabel("SalarioB")
plt.show()

# %% [markdown]
# En este histograma visualizo que hay más personas con pocos años en sus trabajos

# %%
plt.hist(df['Años en la empresa actual'], bins=30)
plt.xlabel('Años en la empresa actual')
plt.ylabel('Frequency')
plt.title('Histograma de Años en la empresa actual')
plt.show()

# %%
# agrupar los datos de años en la empresa actual y SalarioB
grouped = df.groupby('Años en la empresa actual')['SalarioB'].mean()


grouped = grouped[grouped > 1000]


# crear el gráfico de barras
plt.bar(grouped.index, grouped.values)
plt.xlabel('Años en la empresa actual')
plt.ylabel('SalarioB')
plt.title('Salario promedio por Año')
plt.show()

# %%
# agrupar los datos por años trabajados y contar el número de trabajadores por años
grouped = df.groupby('Años en la empresa actual').size()

# seleccionar solo los años con más de 10 trabajadores
grouped = grouped[grouped > 10]

# crear el gráfico de barras
plt.bar(grouped.index, grouped.values)
plt.xlabel('Años en la empresa actual')
plt.ylabel('Cantidad de trabajadores')
plt.title('Cantidad de trabajadores por años trabajados')
plt.show()

# %%
print(df['Años de experiencia'].sort_values(ascending=False)[:30])
print(df['Años de experiencia'].sort_values(ascending=True)[:30])
#Hay valores lógicos con los años de experiencia
# Out:
# Timestamp
# 1/29/2020 17:23:45     45.0
# 1/28/2020 11:37:13     42.0
# 1/17/2020 15:40:57     40.0
# 1/25/2020 8:59:01      40.0
# 2/2/2020 10:32:24      40.0
# 1/31/2020 8:35:02      39.0
# 1/8/2020 13:51:37      38.0
# 1/29/2020 19:43:09     37.0
# 1/28/2020 20:31:01     37.0
# 1/31/2020 18:13:54     36.0
# 1/31/2020 0:36:00      36.0
# 1/30/2020 23:48:04     36.0
# 1/30/2020 8:51:05      35.0
# 1/30/2020 19:46:23     35.0
# 1/30/2020 19:49:42     35.0
# 12/12/2019 16:46:45    35.0
# 1/2/2020 10:24:33      35.0
# 12/13/2019 12:03:14    35.0
# 2/1/2020 13:19:12      35.0
# 1/21/2020 9:06:28      35.0
# 2/1/2020 5:25:28       35.0
# 12/26/2019 13:48:55    35.0
# 1/23/2020 17:17:37     35.0
# 1/17/2020 15:48:58     35.0
# 1/20/2020 15:45:27     35.0
# 2/1/2020 16:21:58      35.0
# 12/13/2019 10:49:15    34.0
# 1/10/2020 14:00:08     34.0
# 1/28/2020 14:43:46     34.0
# 1/30/2020 18:56:19     34.0
# Name: Años de experiencia, dtype: float64
# Timestamp
# 2/2/2020 2:49:47       0.0
# ...

# %%
#Tampoco puedo decir que haya correlación entre los años de experiencia y los salarios
fig=plt.figure()

plt.scatter(df['Años de experiencia'], df['SalarioB'])
plt.xlabel('Años de experiencia')
plt.ylabel("SalarioB")
fig.set_facecolor("white")
plt.show()

# %%
#Los años de experiencia son más diversos, sin embargo la mayoria son menores a 10 años.
plt.hist(df['Años de experiencia'], bins=30)
plt.xlabel('Años de experiencia')
plt.ylabel('Cantidad')
plt.title('Histograma Años de experiencia ')
plt.show()

# %%
# agrupar los datos de años de experiencia y SalarioB
grouped = df.groupby('Años de experiencia')['SalarioB'].mean()

#Intento achicar la cantidad de barras pero no sé como hacerlo. Se nota que los salarios aumentan salvo algún caso extraño
grouped = grouped[grouped > 1000]


# crear el gráfico
plt.bar(grouped.index, grouped.values)
plt.xlabel('Años de experiencia')
plt.ylabel('SalarioB')
plt.title('Salario promedio por Año de experiencia')
plt.show()

# %% [markdown]
# **Hipotesis 4**
#
# *Hipotesis 4: Los salarios más altos corresponde a los técnicos con mayor cantidad de años de experiencia*
#
# **Conclusión 4**
#
# *Hipotesis 4: Dudoso. Los salarios más altos corresponden a los técnicos que poseen más de 10 años de experiencia. Luego hay un estancamiento en el salario. Es decir que una persona que tiene 20 años no suele ganar más de una que tiene 10 años*

# %%
import seaborn as sns

# agrupar los datos por años de experiencia y contar el número de trabajadores por años
grouped = df.groupby('Años de experiencia').size()

# seleccionar solo los años de experiencia con más de 100 trabajadores. Ahora si se puede ver lo que deseaba, a mayor cantidad de experiencia
# los salarios aumentan. Pero se estanca a partir de los 10 años
grouped = grouped[grouped > 100]

# agrupar los datos por años de experiencia y obtener el salario promedio
grouped_salary = df.groupby('Años de experiencia')['SalarioB'].mean()

# seleccionar solo los años de experiencia con más de 100 trabajadores
grouped_salary = grouped_salary[grouped.index]

# crear el gráfico de barras
sns.barplot(x=grouped_salary.index, y=grouped_salary.values)
plt.xlabel('Años de experiencia')
plt.ylabel('Salario promedio')
plt.title('Salario promedio por años de experiencia')
plt.show()

# %% [markdown]
# Para calcular la correlación entre "Años de experiencia" y "SalarioB", utilizo la función pearsonr de scipy.stats de la siguiente manera:

# %%
from scipy.stats import pearsonr

r, p = pearsonr(df['Años de experiencia'], df['SalarioB'])

if p < 0.05:
    print("Hay una correlación significativa (p = {:.3f})".format(p))
else:
    print("No hay una correlación significativa (p = {:.3f})".format(p))
# Out:
# No hay una correlación significativa (p = 0.624)

# %%
#Reviso si hay números negativos
hay_negativos = (df['Años en el puesto actual'] < 0).any()
print(hay_negativos)

# %% [markdown]
# **Hipotesis 5**
#
# *Hipotesis 5: Las personas que mantienen sus puestos de trabajo poseen mayor salarios que los profesionales que recién ingresan a las empresas. Se va a comparar a las personas que tienen menos de 5 años en un mismo puesto*
#
# **Conclusión 5**
#
# *Hipotesis 5: Falso. No se puede identificar una correlación entre los salarios y el tiempo de pertenencia en un puesto laboral*

# %%
bins = [0, 5, 10, 15, 20, 25, 30, 35]
labels = ['0-5', '6-10', '11-15', '16-20', '21-25', '26-30', '31-35']

# agrupar los datos de Años en el puesto actual y SalarioB
Agrupo = df.groupby('Años en el puesto actual')['SalarioB'].mean()

#Intento achicar la cantidad de barras pero no sé como hacerlo. Se nota que los salarios aumentan salvo algún caso extraño
Agrupo = Agrupo[Agrupo > 1000]




# crear el gráfico
plt.bar(Agrupo.index, Agrupo.values)
plt.xlabel('Años en el puesto actual')
plt.ylabel('SalarioB')
plt.title('Salario promedio por Años en el puesto actual')
plt.show()

# %% [markdown]
# Para calcular la correlación entre "Años en el puesto actual" y "SalarioB", utilizo la función pearsonr de scipy.stats de la siguiente manera:

# %%
from scipy.stats import pearsonr

r, p = pearsonr(df['Años en el puesto actual'], df['SalarioB'])

if p < 0.05:
    print("Hay una correlación significativa (p = {:.3f})".format(p))
else:
    print("No hay una correlación significativa (p = {:.3f})".format(p))
# Out:
# No hay una correlación significativa (p = 0.972)

# %%
import seaborn as sns
bins = [0, 5, 10, 15, 20, 25, 30, 35]
labels = ['0-5', '6-10', '11-15', '16-20', '21-25', '26-30', '31-35']
# agrupar los datos por años de experiencia y contar el número de trabajadores por años
Agrupo = df.groupby('Años en el puesto actual').size()

# seleccionar solo los años de experiencia con más de 100 trabajadores. Ahora si se puede ver lo que deseaba, a mayor cantidad de experiencia
# los salarios aumentan. Pero se estanca a partir de los 10 años
Agrupo = Agrupo[Agrupo > 1000]

# agrupar los datos por años de experiencia y obtener el salario promedio
Agrupo_2 = df.groupby('Años en el puesto actual')['SalarioB'].mean()

# seleccionar solo los años de experiencia con más de 1000 trabajadores
Agrupo_2 = Agrupo_2[Agrupo_2.index]

# crear el gráfico de barras
sns.barplot(x=Agrupo_2.index, y=Agrupo_2.values)
plt.xlabel('Años en el puesto actual')
plt.ylabel('Salario promedio')
plt.title('Salario promedio por Años en el puesto actual')
plt.show()

# %%
# Crear una nueva columna con los grupos de Años en el puesto actual (los separo en grupos de a 5) 
bins = [0, 5, 10, 15, 20, 25, 30, 35]
labels = ['0-5', '6-10', '11-15', '16-20', '21-25', '26-30', '31-35']
df['Años en el puesto actual'] = pd.cut(df['Años en el puesto actual'], bins=bins, labels=labels)

# Agrupar los datos por grupo_anios y mostrar la cantidad de filas en cada grupo
grupo_años = df.groupby('Años en el puesto actual').size()
print(grupo_años)
# Out:
# Años en el puesto actual
# 0-5      3467
# 6-10      639
# 11-15     152
# 16-20      37
# 21-25      16
# 26-30       5
# 31-35       1
# dtype: int64

# %%
#Grafico para visualizar que la gran mayoria trabajo menos de 5 años en el mismo puesto
plt.bar(grupo_años.index, grupo_años.values)
plt.xlabel('Años en el mismo puesto')
plt.ylabel('Cantidad de Profesionales')
plt.title('Cantidad de Profesionales y los años en el mismo puesto')
plt.show()

# %%
#En este gráfico podemos contemplar que el salario promedio de quienes trabajan en
#producto basado en software es un poco mayor al resto de las actividades, pero su amplitud de resultados también es mayor
#Por lo cual tampoco hay un gran grado de certeza que tenga mejores salarios
sns.boxplot(data=df, x='SalarioB', y="Actividad principal")
plt.title("Gráfico de Boxplot del tipo de actividad y los salarios", color='black', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Gráfico de Boxplot del tipo de actividad y los salarios')
